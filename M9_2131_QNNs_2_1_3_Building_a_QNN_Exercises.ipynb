# %% [markdown]
# <a href="https://colab.research.google.com/github/james-lucius/qureca_ADEQUATE/blob/main/M9_2131_QNNs_2_1_3_Building_a_QNN_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://gitlab.com/qworld/qeducation/educational-materials/adequate-qbook1/raw/main/qworld/images/adq_1.png" align="left" width=450>

# %% [markdown]
# _prepared by Claudia Zendejas-Morales_

# %% [markdown]
# ### 2.1.3 Building a QNN Exercises

# %% [markdown]
# ##### <font color="#08b806">Please run the following (hidden) cell; it is required to set up the environment for Google Colab

# %%
import IPython

def in_colab():
    try:
        import google.colab
        return True
    except:
        return False

SolutionToTask1 = lambda: IPython.display.display(IPython.display.Javascript('window.open("{url}");'.format(url='https://colab.research.google.com/drive/1vqo2RRKLVfdRh3lml2WferO-SviwhoZZ#scrollTo=6Wb6q_CsQLso' if in_colab() else 'QNNs - 2.1.3 Building a QNN Exercises Solutions.ipynb#task1')))
SolutionToTask2 = lambda: IPython.display.display(IPython.display.Javascript('window.open("{url}");'.format(url='https://colab.research.google.com/drive/1vqo2RRKLVfdRh3lml2WferO-SviwhoZZ#scrollTo=j0pBDptgmKKU' if in_colab() else 'QNNs - 2.1.3 Building a QNN Exercises Solutions.ipynb#task2')))
SolutionToTask3 = lambda: IPython.display.display(IPython.display.Javascript('window.open("{url}");'.format(url='https://colab.research.google.com/drive/1vqo2RRKLVfdRh3lml2WferO-SviwhoZZ#scrollTo=qNqtRNvHp3Jy' if in_colab() else 'QNNs - 2.1.3 Building a QNN Exercises Solutions.ipynb#task3')))
SolutionToTask4 = lambda: IPython.display.display(IPython.display.Javascript('window.open("{url}");'.format(url='https://colab.research.google.com/drive/1vqo2RRKLVfdRh3lml2WferO-SviwhoZZ#scrollTo=GG9poudltU90' if in_colab() else 'QNNs - 2.1.3 Building a QNN Exercises Solutions.ipynb#task4')))

if in_colab():
    # !pip install qiskit[visualization]==1.4.2 &> /dev/null # use "&> /dev/null" so that the standard output of the installation is not displayed

# %% [markdown]
# <a name="task1"></a>
# ## Task 1
#
# Create a function that generates a quantum circuit in Qiskit, encoding $2n$ features using $n$ qubits with rotations; that is, it will ultimately return an **angle encoding** feature map.
#
# Let us recall the image at the end of the "2.1.1 Angle (Rotation) Encoding" section:

# %% [markdown]
# <center><img width="450px" src="data:image/png;base64,...">

# %% [markdown]
# Don't forget that the feature vector must be normalized to be in the range $[0, \pi]$.

# %%
import math

def normalize_features(features):
  pass  ### your code goes here

# %%
from qiskit import QuantumCircuit

def angle_encoding_2n(features):
  pass  ### your code goes here

# %% [markdown]
# To check out our solution, run the next cell:

# %%
SolutionToTask1()  # show solution for task 1

# %% [markdown]
# <a name="task2"></a>
# ## Task 2 (on paper)
#
# Using **basis encoding**, find the state that represents the classical dataset containing the following two data points:
#
# $$x^1=01\quad\quad;\quad\quad x^2=11$$

# %% [markdown]
# To check out our solution, run the next cell:

# %%
SolutionToTask2()  # show solution for task 2

# %% [markdown]
# <a name="task3"></a>
# ## Task 3
#
# The Qiskit framework has an implementation of the **ZZ Feature Map**; you can check it out [here](https://docs.quantum.ibm.com/api/qiskit/qiskit.circuit.library.ZZFeatureMap).
#
# Explore this class, which returns a quantum circuit with this feature map implementation. Try it with $n=3, 5, 10$.
#
# Use `reps=1` to check the gates more easily.
#
# What happens if you change the `entanglement` parameter? What are the options for this parameter?

# %%
### your code goes here

# %% [markdown]
# To check out our solution, run the next cell:

# %%
SolutionToTask3()  # show solution for task 3

# %% [markdown]
# <a name="task4"></a>
# ## Task 4
#
# Write a function in Qiskit that generates the **two-local** ansatz for $n$ qubits, with $k$ layers and the parameters $\boldsymbol{\theta}$, the three values received as arguments.
#
# Let us recall the image of the "2.1.2 Two-Local Ansatz" section:

# %% [markdown]
# <center><img width="550px" src="data:image/png;base64,...">

# %%
from qiskit import QuantumCircuit

def TwoLocal(n, k, theta):
  pass  ### your code goes here

# %% [markdown]
# To check out our solution, run the next cell:

# %%
SolutionToTask4()  # show solution for task 4
